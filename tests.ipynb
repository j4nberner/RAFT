# %%
import cv2

# %%
import cv2

image_path = 'habitat_images/frame_1.png'
image_path2 = 'demo-frames/frame_0016.png'
image = cv2.imread(image_path)
img2 = cv2.imread(image_path2)

# %%
img2.shape
# Out:
# (436, 1024, 3)

# %%
# Display the image
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# QObject::moveToThread: Current thread (0x5a9b06cb37b0) is not the object's thread (0x5a9b06d759a0).
# Cannot move to target thread (0x5a9b06cb37b0)
#
# ...
